# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
datasets = {1: 'data/IT2/RegressionContrastive', 
            2: 'data/IT2/Contrastive', 
            #3: 'data/IT2/ContinuedContrastive', 
            4: 'data/IT2/OnlyPositiveContrastive',
            5: 'data/IT2/RegContrastiveContinued',
            6: 'data/IT2/CDFTobit/epoch_180',
            7: 'data/IT3/LogTobitAndCDF',
            8: 'data/IT3/LogTobitAndCDF1',
            9: 'data/IT3/RegressionNegNum1',
            10: 'data/IT2/ContrastiveVariantMSE',
            12: 'data/IT4/MSEAndContrastive/Test',
            13: 'data/IT4/Contrastive/Train',
            14: 'data/IT4/MSEContrativeCombined/Test',
            15: 'data/IT4/MSEOnlyPosZurich/Train',
            16: 'data/IT5/MSEAndContrastive400/Train',
            18: 'data/IT5/MSEAndContrastive20Meter400/Test'}

no = 13
gps = np.genfromtxt(f'{datasets[no]}/gps.csv', delimiter=',')
emb = np.genfromtxt(f'{datasets[no]}/embedding.csv', delimiter=',')
emb = 1-emb

# filter away negatives
for i in range(len(gps)):
    gps[i][gps[i] > 25] = 0
    emb[i][gps[i] > 25] = 1

# %% [markdown]
# # Correlation

# %%
positive_emb = emb[gps != 0].reshape(-1, 1)
positive_gps = gps[gps != 0].reshape(-1, 1)

reg = LinearRegression().fit(positive_gps, positive_emb)
mse = mean_squared_error(positive_emb, reg.predict(positive_gps))
print(f'MSE: {mse}')
print(f'Gradient: {reg.coef_[0]}')

predicted = reg.predict(positive_gps)


#Plot
fig, axs = plt.subplots(1, 1, figsize=(20,10))
axs.scatter(positive_gps, positive_emb, color='b')
axs.plot(positive_gps, predicted, color='red', linewidth=3)
axs.set_xlim([0, 25])
axs.set_ylim([0.0, 1.0])
# Out:
# MSE: 0.0009760153921028396
# Gradient: [0.00056042]
# (0.0, 1.0)

# %% [markdown]
# # Kendall's Tau

# %%
def kendalltau(ranking_a, ranking_b):
    return stats.kendalltau(np.argsort(ranking_a), np.argsort(ranking_b))

# %%
def kt_scores():
    N = len(gps)
    scores = np.zeros(N)
    for i in range(N):
        c, p = kendalltau(gps[i], emb[i])
        scores[i] = c
    print(np.mean(scores), np.max(scores))
    return scores

def MSE_scores():
    scores = []
    for i in range(len(gps)):
        emb_i = emb[i][gps[i] != 0]
        gps_i = gps[i][gps[i] != 0]
        if len(gps_i) > 2:
            y = (gps_i)**2 / 35**2
            scores.append(mean_squared_error(y, emb_i))
    print(np.mean(scores), np.max(scores))
    return scores

def linear_regression_predict(gps, emb):
    reshaped_gps = gps.reshape(-1, 1)
    reshaped_emb = emb.reshape(-1, 1)
    reg = LinearRegression().fit(reshaped_gps, reshaped_emb)
    return reg, reg.predict(reshaped_gps)

def correlation_scores():
    scores = []
    for i in range(len(gps)):
        emb_i = emb[i][gps[i] != 0]
        gps_i = gps[i][gps[i] != 0]
        if len(gps_i) > 2:
            reg, _ = linear_regression_predict(gps_i, emb_i)
            scores.append(reg.coef_[0][0])
    print(np.mean(scores), np.max(scores))
    return scores

# %%
#contrastive = kt_scores()
#mse = kt_scores()
#mse_only = kt_scores()
# Out:
# -0.01258490324234269 0.7333333333333333

# %%
bins_list = np.linspace(-1, 1, num=25)
plt.hist(contrastive, alpha=0.5, label='Contrastive', bins=bins_list)
plt.hist(mse, alpha=0.5, label='MSE (Only Positive)', bins=bins_list)
plt.hist(mse_only, alpha=0.5, label='MSE', bins=bins_list)
plt.title("Kendall's Tau Distribution")
plt.legend()
plt.show()

# %%
#contrastive = MSE_scores()
#mse = MSE_scores()
#mse_only = MSE_scores()
# Out:
# 0.032870695682513905 0.1331872177448922

# %%
bins_list = np.linspace(0, 0.15, num=25)
plt.hist(contrastive, alpha=0.5, label='Contrastive', bins=bins_list)
plt.hist(mse_only, alpha=0.5, label='MSE (Only Positive)', bins=bins_list)
plt.hist(mse, alpha=0.5, label='MSE', bins=bins_list)
plt.title('Mean Squared Error')
plt.legend()

# %%
contrastive = correlation_scores()
#mse = correlation_scores()
#mse_only = correlation_scores()

# %%
contrastive

# %%
bins_list = np.linspace(0, 0.15, num=25)
plt.hist(contrastive, alpha=0.5, label='Contrastive', bins=bins_list)
#plt.hist(mse_only, alpha=0.5, label='MSE (Only Positive)', bins=bins_list)
#plt.hist(mse, alpha=0.5, label='MSE', bins=bins_list)
plt.title('Mean Squared Error')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-35a35280b472> in <module>
#       1 bins_list = np.linspace(0, 0.15, num=25)
# ----> 2 plt.hist(contrastive, alpha=0.5, label='Contrastive', bins=bins_list)
#       3 #plt.hist(mse_only, alpha=0.5, label='MSE (Only Positive)', bins=bins_list)
#       4 #plt.hist(mse, alpha=0.5, label='MSE', bins=bins_list)
#       5 plt.title('Mean Squared Error')
#
# /usr/local/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6589             # this will automatically overwrite bins,
#    6590             # so that each histogram uses the same bins
# -> 6591             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6592             m = m.astype(float)  # causes problems later if it's an int
#    6593             if mlast is None:
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     864             for i in _range(0, len(a), BLOCK):
#     865                 sa = np.sort(a[i:i+BLOCK])
# --> 866                 cum_n += _search_sorted_inclusive(sa, bin_edges)
#     867         else:
#     868             zero = np.zeros(1, dtype=ntype)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py in _search_sorted_inclusive(a, v)
#     450     """
#     451     return np.concatenate((
# --> 452         a.searchsorted(v[:-1], 'left'),
#     453         a.searchsorted(v[-1:], 'right')
#     454     ))
#
# TypeError: '<' not supported between instances of 'NoneType' and 'float'
