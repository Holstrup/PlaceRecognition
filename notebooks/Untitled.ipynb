# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import random
import cv2

# %%
gps = np.loadtxt('data/LocalCorrelation/gps.txt')
emb = np.loadtxt('data/LocalCorrelation/embedding.txt')

# %%
plt.scatter(gps[gps <= 15], emb[gps <= 15])
